# %%
import pandas as pd
import geopandas as gpd
import xarray as xr
import rioxarray
import numpy as np
import rasterio 
import os
import csv
import matplotlib.pyplot as plt
import seaborn as sns
from shapely.geometry import mapping

# %%
os.chdir('/home/h99g576/Zambia_SPEI/')

# %%
# load Zambia shapefile
zambia = 'Data/zm.shp'
# read shapefile into geodataframe
gdf = gpd.read_file(zambia)

# %%
gdf.head()

# %%
# plot data
gdf.plot(figsize=(10, 10))
plt.show()

# %%
print(gdf.crs)
# Out:
# EPSG:4326

# %%
# import ESSD Copernicus SPEI data
spei_file = 'Data/spei48.nc'
spei_data = xr.open_dataset(spei_file)

# %%
# set shapefile CRS
gdf.crs = 'EPSG:4326'

# %%
print(spei_data)
# Out:
# <xarray.Dataset> Size: 29GB
# Dimensions:  (lon: 7200, lat: 2000, time: 504)
# Coordinates:
#   * lon      (lon) float64 58kB -180.0 -179.9 -179.9 ... 179.9 179.9 180.0
#   * lat      (lat) float64 16kB -49.97 -49.92 -49.88 ... 49.87 49.92 49.97
#   * time     (time) datetime64[ns] 4kB 1981-01-01 1981-02-01 ... 2022-12-16
# Data variables:
#     spei     (time, lat, lon) float32 29GB ...
# Attributes: (12/14)
#     Title:        Global 48-months SPEI, z-values, 0.05 degree
#     Version:      2.6
#     Id:           /mainfs/evoflood/SPEI/SPEI/CHIRPS_GLEAM/spei48.nc
#     Summary:      Global dataset of the Standardized\n\t  Precipitation-Evapo...
#     Keywords:     drought, climatology, SPEI, Standardized\n\t  Precipitation...
#     Institution:  Consejo Superior de Investigaciones\n\t          Científica...
#     ...           ...
#     Software:     Created in R using the SPEI package\n\t          (https://c...
#     Call:         spei.nc(sca=i, inPre=/mainfs/evoflood/SPEI/Prcp/Prcp_chirps...
#     Date:         Thu May  4 23:09:13 2023
#     Reference:    Beguería S., Vicente-Serrano S., Reig F., Latorre B. (2014)...
#     Reference2:   Vicente-Serrano S.M., Beguería S., López-Moreno J.I. (2010)...
#     Reference3:   Beguería S., Vicente-Serrano S., Angulo-Martínez M. (2010) ...

# %%
# ensure 'time' variable is in right format
spei_data['time'] = pd.to_datetime(spei_data['time'].values)

# %%
# filter SPEI data to get only data from 2000-2020
spei_data_filtered = spei_data.sel(time=slice('2000-01-01', '2020-12-31'))

# %%
# set spatial dimensions
spei_data_filtered.rio.set_spatial_dims(x_dim = 'lon', y_dim = 'lat', inplace = True)
# Out:
# <xarray.Dataset> Size: 15GB
# Dimensions:  (lon: 7200, lat: 2000, time: 252)
# Coordinates:
#   * lon      (lon) float64 58kB -180.0 -179.9 -179.9 ... 179.9 179.9 180.0
#   * lat      (lat) float64 16kB -49.97 -49.92 -49.88 ... 49.87 49.92 49.97
#   * time     (time) datetime64[ns] 2kB 2000-01-01 2000-02-01 ... 2020-12-01
# Data variables:
#     spei     (time, lat, lon) float32 15GB ...
# Attributes: (12/14)
#     Title:        Global 48-months SPEI, z-values, 0.05 degree
#     Version:      2.6
#     Id:           /mainfs/evoflood/SPEI/SPEI/CHIRPS_GLEAM/spei48.nc
#     Summary:      Global dataset of the Standardized\n\t  Precipitation-Evapo...
#     Keywords:     drought, climatology, SPEI, Standardized\n\t  Precipitation...
#     Institution:  Consejo Superior de Investigaciones\n\t          Científica...
#     ...           ...
#     Software:     Created in R using the SPEI package\n\t          (https://c...
#     Call:         spei.nc(sca=i, inPre=/mainfs/evoflood/SPEI/Prcp/Prcp_chirps...
#     Date:         Thu May  4 23:09:13 2023
#     Reference:    Beguería S., Vicente-Serrano S., Reig F., Latorre B. (2014)...
#     Reference2:   Vicente-Serrano S.M., Beguería S., López-Moreno J.I. (2010)...
#     Reference3:   Beguería S., Vicente-Serrano S., Angulo-Martínez M. (2010) ...

# %%
# define CRS 
spei_data_filtered.rio.write_crs('EPSG:4326', inplace = True)
# Out:
# <xarray.Dataset> Size: 15GB
# Dimensions:      (lon: 7200, lat: 2000, time: 252)
# Coordinates:
#   * lon          (lon) float64 58kB -180.0 -179.9 -179.9 ... 179.9 179.9 180.0
#   * lat          (lat) float64 16kB -49.97 -49.92 -49.88 ... 49.87 49.92 49.97
#   * time         (time) datetime64[ns] 2kB 2000-01-01 2000-02-01 ... 2020-12-01
#     spatial_ref  int64 8B 0
# Data variables:
#     spei         (time, lat, lon) float32 15GB ...
# Attributes: (12/14)
#     Title:        Global 48-months SPEI, z-values, 0.05 degree
#     Version:      2.6
#     Id:           /mainfs/evoflood/SPEI/SPEI/CHIRPS_GLEAM/spei48.nc
#     Summary:      Global dataset of the Standardized\n\t  Precipitation-Evapo...
#     Keywords:     drought, climatology, SPEI, Standardized\n\t  Precipitation...
#     Institution:  Consejo Superior de Investigaciones\n\t          Científica...
#     ...           ...
#     Software:     Created in R using the SPEI package\n\t          (https://c...
#     Call:         spei.nc(sca=i, inPre=/mainfs/evoflood/SPEI/Prcp/Prcp_chirps...
#     Date:         Thu May  4 23:09:13 2023
#     Reference:    Beguería S., Vicente-Serrano S., Reig F., Latorre B. (2014)...
#     Reference2:   Vicente-Serrano S.M., Beguería S., López-Moreno J.I. (2010)...
#     Reference3:   Beguería S., Vicente-Serrano S., Angulo-Martínez M. (2010) ...

# %%
# convert 'time' coordinate to datetime
spei_data_filtered['time'] = pd.to_datetime(spei_data_filtered['time'].values)

# %%
print(spei_data_filtered.coords['time'])
# Out:
# <xarray.DataArray 'time' (time: 252)> Size: 2kB
# array(['2000-01-01T00:00:00.000000000', '2000-02-01T00:00:00.000000000',
#        '2000-03-01T00:00:00.000000000', ..., '2020-10-01T00:00:00.000000000',
#        '2020-11-01T00:00:00.000000000', '2020-12-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time         (time) datetime64[ns] 2kB 2000-01-01 2000-02-01 ... 2020-12-01
#     spatial_ref  int64 8B 0

# %%
# create variable identifying province names
provinces = gdf['name'].unique()
print(provinces)
# Out:
# ['Muchinga' 'Eastern' 'Northern' 'Lusaka' 'Southern' 'Western'
#  'North-Western' 'Luapula' 'Copperbelt' 'Central']

# %%
# resample data to monthly and calculate average
spei_monthly = spei_data_filtered.resample(time='ME').mean()

# %%
# set spatial dimensions
spei_monthly = spei_monthly.rio.set_spatial_dims('lon', 'lat')

# %%
# set CRS
spei_monthly = spei_monthly.rio.write_crs('EPSG:4326', inplace=True)

# %%
print(spei_monthly.coords['time'])
# Out:
# <xarray.DataArray 'time' (time: 252)> Size: 2kB
# array(['2000-01-31T00:00:00.000000000', '2000-02-29T00:00:00.000000000',
#        '2000-03-31T00:00:00.000000000', ..., '2020-10-31T00:00:00.000000000',
#        '2020-11-30T00:00:00.000000000', '2020-12-31T00:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time         (time) datetime64[ns] 2kB 2000-01-31 2000-02-29 ... 2020-12-31
#     spatial_ref  int64 8B 0

# %%
for province in provinces:
    province_geom = gdf[gdf['name'] == province].geometry.iloc[0]
    spei_clipped = spei_monthly.rio.clip([mapping(province_geom)], crs=gdf.crs)
    spei_variable = spei_clipped['spei']
    
    # plot first time step
    spei_variable.sel(time='2000-01-31').plot(figsize=(10, 8))
    
    plt.title(f'Monthly Average SPEI for {province} on 2000-01-01')
    plt.show()

# %%
print(gdf.columns)
# Out:
# Index(['id', 'name', 'source', 'geometry'], dtype='object')

# %% [markdown]
# ## District Level

# %%
# load districts shapefile
district_level = 'Data/district.shp'
# read shapefile into geodataframe
gdf_districts = gpd.read_file(district_level)

# %%
# create variable identifying district names
districts = gdf_districts['NAME_2'].unique()
print(len(districts))
# Out:
# 115

# %%
# set CRS
gdf_districts.crs = 'EPSG:4326'

# %%
# extract district geometry
district_geom = gdf_districts[gdf_districts['NAME_2'] == districts].geometry.iloc[0]

# %%
import dask.array as da

# set spatial dimensions for dask array
spei_monthly_dask = spei_monthly.chunk({'lat': 100, 'lon': 100})
spei_monthly_dask = spei_monthly_dask.rio.set_spatial_dims('lon', 'lat')

# clip data
spei_clipped = spei_monthly_dask.rio.clip([mapping(district_geom)], crs = gdf.crs)

# %%
# calculate area averages
area_avg = spei_clipped.mean(dim=['lat', 'lon'], skipna=True)
print(area_avg['spei'].shape)
# Out:
# (252,)

# %%
# convert 'time' to datetime
time_values = spei_clipped['time'].values
time_dates = pd.to_datetime(time_values)

# compute area average
area_avg_computed = area_avg['spei'].compute()

# plot time series
plt.figure(figsize=(10,6))
plt.plot(time_dates, area_avg_computed, label = 'Average SPEI')
plt.xlabel('Time')
plt.ylabel('Average SPEI')
plt.title('Time Series of Average SPEI')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### Specific districts

# %%
# Mansa, for example
district_name = 'Mansa'

# extract geometry
district_geom = gdf_districts[gdf_districts['NAME_2'] == district_name].geometry.iloc[0]

# clip SPEI monthly dataset
spei_clipped_district = spei_monthly.rio.clip([mapping(district_geom)], crs = gdf_districts.crs)

# compute area average
area_avg_district = spei_clipped_district.mean(dim = ['lat', 'lon'], skipna = True)

# convert to datetime
time_values = spei_clipped_district['time'].values
time_dates = pd.to_datetime(time_values)

# compute area average values
area_avg_district_computed = area_avg_district['spei'].compute()

# %%
# plot time series for Mansa
plt.figure(figsize = (10, 6))
plt.plot(time_dates, area_avg_district_computed, label = f'Average SPEI - {district_name}')
plt.xlabel('Time')
plt.ylabel('Average SPEI')
plt.title(f'Time Series of Average SPEI for {district_name} District')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Code graveyard

# %%
# create list to store results
district_time_series = {}

# loop to clip SPEI data for each district
for district in districts:
    # extract district geometry
    district_geom = gdf_districts[gdf_districts['NAME_2'] == district].geometry.iloc[0]
    # clip SPEI by district geometry
    spei_clipped = spei_monthly.rio.clip([mapping(district_geom)], crs=gdf.crs)
    # extract SPEI variable and calculate area average
    spei_variable = spei_clipped['spei']
    area_avg = spei_variable.mean(dim=['lat', 'lon'], skipna = True)

# %%
import glob

# %%
from glob import glob

# %%
file_list = sorted(glob.glob('*.nc'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 file_list = sorted(glob.glob('*.nc'))
#
# AttributeError: 'function' object has no attribute 'glob'

# %%
for file in file_list:
    nc_file = xarray.open_dataset(file)
    clipped_nc = nc_file.rio.clip(gdf.geometry.apply(mapping), gdf.crs, all_touched = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 for file in file_list:
#       2     nc_file = xarray.open_dataset(file)
#       3     clipped_nc = nc_file.rio.clip(gdf.geometry.apply(mapping), gdf.crs, all_touched = True)
#
# NameError: name 'file_list' is not defined

# %%
# create zambia shapefile mask
zambia_mask = rasterio.features.geometry_mask(gdf.iloc[0],
                                              out_shape = (len(spei.y), len(spei.x)),
                                              transform = spei.geobox.transform,
                                              invert = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 # create zambia shapefile mask
#       2 zambia_mask = rasterio.features.geometry_mask(gdf.iloc[0],
# ----> 3                                               out_shape = (len(spei.y), len(spei.x)),
#       4                                               transform = spei.geobox.transform,
#       5                                               invert = True)
#
# NameError: name 'spei' is not defined

# %%
spei_raster = spei_data['spei']

# %%
spei_raster.rio.write_crs("EPSG:4326", inplace=True)  # Set the CRS for the raster data if not defined

# Step 5: Reproject the GeoDataFrame to the same CRS as the raster (if needed)
gdf = gdf.to_crs(spei_raster.rio.crs)

# %%
# Set spatial dimensions explicitly for rioxarray
spei_raster = spei_raster.rename({'lat': 'y', 'lon': 'x'})

# Now we can clip the raster
clip_geometry = gdf.geometry.apply(mapping)
clipped_spei = spei_raster.rio.clip(clip_geometry, gdf.crs)

# Plot the clipped data
plt.figure(figsize=(10, 10))
clipped_spei.plot()
plt.title('Clipped SPEI Data for Zambia')
plt.show()

# %%
# clip SPEI raster to Zambia shapefile
clip_geometry = gdf.geometry.apply(mapping)
clipped_spei = spei_raster.rio.clip(clip_geometry, gdf.crs)
# Out:
# ---------------------------------------------------------------------------
# MissingSpatialDimensionError              Traceback (most recent call last)
# Cell In[24], line 3
#       1 # clip SPEI raster to Zambia shapefile
#       2 clip_geometry = gdf.geometry.apply(mapping)
# ----> 3 clipped_spei = spei_raster.rio.clip(clip_geometry, gdf.crs)
#
# File /mnt/shared/moduleapps/EarthSci/Python-3.9.15-Mamba/lib/python3.9/site-packages/rioxarray/raster_array.py:911, in RasterArray.clip(self, geometries, crs, all_touched, drop, invert, from_disk)
#     903     cropped_ds = _clip_from_disk(
#     904         self._obj,
#     905         geometries=geometries,
#    (...)
#     908         invert=invert,
#     909     )
#     910 if cropped_ds is None:
# --> 911     cropped_ds = _clip_xarray(
#     912         self._obj,
#     913         geometries=geometries,
#     914         all_touched=all_touched,
#     915         drop=drop,
#     916         invert=invert,
#     917     )
#     919 if (
#     920     cropped_ds.coords[self.x_dim].size < 1
#     921     or cropped_ds.coords[self.y_dim].size < 1
#     922 ):
#     923     raise NoDataInBounds(
#     924         f"No data found in bounds.{_get_data_var_message(self._obj)}"
#     925     )
#
# File /mnt/shared/moduleapps/EarthSci/Python-3.9.15-Mamba/lib/python3.9/site-packages/rioxarray/raster_array.py:205, in _clip_xarray(xds, geometries, all_touched, drop, invert)
#     193 def _clip_xarray(
#     194     xds: xarray.DataArray,
#     195     geometries: Iterable,
#    (...)
#     198     invert: bool,
#     199 ) -> xarray.DataArray:
#     200     """
#     201     clip the xarray DataArray
#     202     """
#     203     clip_mask_arr = geometry_mask(
#     204         geometries=geometries,
# --> 205         out_shape=(int(xds.rio.height), int(xds.rio.width)),
#     206         transform=xds.rio.transform(recalc=True),
#     207         invert=not invert,
#     208         all_touched=all_touched,
#     209     )
#     210     clip_mask_xray = xarray.DataArray(
#     211         clip_mask_arr,
#     212         dims=(xds.rio.y_dim, xds.rio.x_dim),
#     213     )
#     214     cropped_ds = xds.where(clip_mask_xray)
#
# File /mnt/shared/moduleapps/EarthSci/Python-3.9.15-Mamba/lib/python3.9/site-packages/rioxarray/rioxarray.py:904, in XRasterBase.height(self)
#     902 if self._height is not None:
#     903     return self._height
# --> 904 self._height = self._obj[self.y_dim].size
#     905 return self._height
#
# File /mnt/shared/moduleapps/EarthSci/Python-3.9.15-Mamba/lib/python3.9/site-packages/rioxarray/rioxarray.py:885, in XRasterBase.y_dim(self)
#     883 if self._y_dim is not None:
#     884     return self._y_dim
# --> 885 raise MissingSpatialDimensionError(
#     886     "y dimension not found. 'rio.set_spatial_dims()' or "
#     887     "using 'rename()' to change the dimension name to 'y' can address this."
#     888     f"{_get_data_var_message(self._obj)}"
#     889 )
#
# MissingSpatialDimensionError: y dimension not found. 'rio.set_spatial_dims()' or using 'rename()' to change the dimension name to 'y' can address this. Data variable: spei

# %%
clipped = raster.clip(gdf.geometry.apply(mapping), gdf.crs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 clipped = raster.clip(gdf.geometry.apply(mapping), gdf.crs)
#
# NameError: name 'raster' is not defined
