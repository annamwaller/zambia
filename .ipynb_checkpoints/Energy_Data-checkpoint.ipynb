# %%
import pandas as pd
import numpy as np
import rasterio
import os
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir('/home/h99g576/Zambia_Energy/')

# %%
# load International Energy Agency (IEA) electricity generation data
df = pd.read_csv('Data/electricity_generation.csv')
df.head()
# Out:
#   electricity generation in Zambia  Value  Year Units
# 0                             Coal   14.0  2000   GWh
# 1                             Coal   15.0  2001   GWh
# 2                             Coal   16.0  2002   GWh
# 3                             Coal   17.0  2003   GWh
# 4                             Coal   13.0  2004   GWh

# %%
sns.lineplot(data=df, x='Year', y='Value', hue='electricity generation in Zambia')
# Out:
# <Axes: xlabel='Year', ylabel='Value'>

# %%
# IEA energy consumption by sector data
consumption_df = pd.read_csv('Data/consumption_by_sector.csv')
consumption_df.head()
# Out:
#   total final consumption in Zambia  Value  Year Units
# 0                   Industry Sector  33390  2000    TJ
# 1                   Industry Sector  35853  2001    TJ
# 2                   Industry Sector  39598  2002    TJ
# 3                   Industry Sector  43076  2003    TJ
# 4                   Industry Sector  43785  2004    TJ

# %%
sns.lineplot(data=consumption_df, x='Year', y='Value', hue='total final consumption in Zambia')
# Out:
# <Axes: xlabel='Year', ylabel='Value'>

# %%
# IEA total consumption data
total_consumption = pd.read_csv('Data/total_final_consumption.csv')
total_consumption.head()
# Out:
#   total final consumption in Zambia  Value  Year Units
# 0                              Coal   2940  2000    TJ
# 1                              Coal   3088  2001    TJ
# 2                              Coal   3211  2002    TJ
# 3                              Coal   3409  2003    TJ
# 4                              Coal   2445  2004    TJ

# %%
sns.lineplot(data=total_consumption, x = 'Year', y = 'Value', hue = 'total final consumption in Zambia')
# Out:
# <Axes: xlabel='Year', ylabel='Value'>
